# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd 

# Reading the CSV file containing shopping behavior data into a DataFrame
df = pd.read_csv("shopping_behavior.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# Rounding the 'Review Rating' column to nearest integer and converting it to integer type
df['Review Rating'] = df['Review Rating'].round().astype(int)

# Displaying the DataFrame after rounding the 'Review Rating' column
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# Generating descriptive statistics for the DataFrame
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.780513
# std    1125.977353    15.207589              23.685392       0.751184
# min       1.000000    18.000000              20.000000       2.000000
# 25%     975.750000    31.000000              39.000000       3.000000
# 50%    1950.500000    44.000000              60.000000       4.000000
# 75%    2925.250000    57.000000              81.000000       4.000000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
# Providing information about the DataFrame including data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   int32
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
# List of categorical columns in the DataFrame
category_of_columns = ['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color', 'Season', 'Subscription Status', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Payment Method', 'Frequency of Purchases']

# %%
# Iterating through each categorical column to display unique values and their counts
for i in category_of_columns:
    print(f"\nUnique values and count for {i}:\n{df[i].value_counts()}")
# Out:
# Unique values and count for Gender:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64
#
# Unique values and count for Item Purchased:
# Item Purchased
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64
#
# Unique values and count for Category:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64
#
# Unique values and count for Location:
# Location
# Montana           96
# California        95
# Idaho             93
# ...

# %%
# Calculating the count of missing values in each column
mv = df.isnull().sum()

# %%
# Displaying the count of missing values
mv
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
# Counting the occurrences of each category in the 'Category' column
category_count = df['Category'].value_counts()

# Displaying the count of occurrences for each category
category_count
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt

# Plotting a bar chart to visualize the count of products sold per category
category_count.plot(kind='bar', color='mediumorchid')

# Adding labels to the x-axis and y-axis
plt.xlabel('Categories')
plt.ylabel('Number of Products Sold')

# Adding a title to the plot
plt.title('Products Sold per Category')

# Displaying the plot
plt.show()

# %%
# Grouping the DataFrame by 'Item Purchased' and 'Season', and calculating the size of each group
item_and_season = df.groupby(['Item Purchased', 'Season']).size()

# Printing the resulting Series showing the count of occurrences for each combination of 'Item Purchased' and 'Season'
print(item_and_season)
# Out:
# Item Purchased  Season
# Backpack        Fall      34
#                 Spring    39
#                 Summer    45
#                 Winter    25
# Belt            Fall      41
#                           ..
# Sweater         Winter    42
# T-shirt         Fall      39
#                 Spring    38
#                 Summer    30
#                 Winter    40
# Length: 100, dtype: int64

# %%
# Unstacking the multi-index Series to convert it into a DataFrame
item_and_season = item_and_season.unstack()

# Printing the DataFrame, where rows represent items purchased and columns represent seasons,
# with values indicating the count of purchases for each combination of item and season
print(item_and_season)
# Out:
# Season          Fall  Spring  Summer  Winter
# Item Purchased
# Backpack          34      39      45      25
# Belt              41      41      39      40
# Blouse            42      46      43      40
# Boots             35      40      38      31
# Coat              34      46      42      39
# Dress             36      43      47      40
# Gloves            37      42      29      32
# Handbag           48      36      35      34
# Hat               50      27      37      40
# Hoodie            36      36      31      48
# Jacket            54      35      33      41
# Jeans             32      32      31      29
# Jewelry           35      42      47      47
# Pants             38      32      50      51
# Sandals           44      44      40      32
# Scarf             40      41      43      33
# Shirt             39      42      38      50
# Shoes             26      40      46      38
# Shorts            35      47      40      35
# ...

# %%
# Calculating the count of missing values in each column of the item_and_season DataFrame
missing_values_count = item_and_season.isnull().sum()

# Printing the count of missing values in each column
print(missing_values_count)
# Out:
# Season
# Fall      0
# Spring    0
# Summer    0
# Winter    0
# dtype: int64

# %%
#color map for Graphs
colors={'Fall':'Teal','Spring':'orange','Summer':'red','Winter':'cyan'}

# %%
# Plotting a stacked bar plot to visualize the count of items sold per season
item_and_season.plot(kind='bar', stacked=True, colormap='viridis', color=[colors[season] for season in item_and_season.columns])

# Adding labels to the x-axis and y-axis
plt.xlabel("ITEM PURCHASED")
plt.ylabel("COUNT OF CUSTOMERS")

# Adding a title to the plot
plt.title("Count of Items Sold per Season")

# Displaying the plot
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_11968\1671810767.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   item_and_season.plot(kind='bar', stacked=True, colormap='viridis', color=[colors[season] for season in item_and_season.columns])
# C:\Users\shiva\AppData\Local\Temp\ipykernel_11968\1671810767.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   item_and_season.plot(kind='bar', stacked=True, colormap='viridis', color=[colors[season] for season in item_and_season.columns])

# %%
# Prompting the user to enter the season they want to visualize
filter_season = input("Enter the season you want to visualize: ")

# Creating a filter condition to select rows where the 'Season' column matches the entered season
filter_condition = (df['Season'] == filter_season)

# Filtering the DataFrame based on the condition
filtered_df = df[filter_condition]
# Out:
# Enter the season you want to visualize: Spring

# %%
# Grouping the filtered DataFrame by 'Item Purchased' and 'Season', calculating the size of each group, and unstacking the result
item_and_season = filtered_df.groupby(['Item Purchased','Season']).size().unstack()

# Plotting a stacked bar plot to visualize the count of items sold per season
item_and_season.plot(kind='bar', stacked=True, colormap='viridis', color=[colors[season] for season in item_and_season.columns])

# Adding labels to the x-axis and y-axis
plt.xlabel("ITEM PURCHASED")
plt.ylabel("COUNT OF CUSTOMERS")

# Adding a title to the plot
plt.title("Count of Items Sold per Season")

# Displaying the plot
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_11968\2077941086.py:5: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   item_and_season.plot(kind='bar', stacked=True, colormap='viridis', color=[colors[season] for season in item_and_season.columns])
# C:\Users\shiva\AppData\Local\Temp\ipykernel_11968\2077941086.py:5: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   item_and_season.plot(kind='bar', stacked=True, colormap='viridis', color=[colors[season] for season in item_and_season.columns])

# %% [markdown]
# # Recommendation system

# %%
# Importing necessary modules
from colorama import Fore, Style  # Importing colorama for colored text in terminal 
from surprise import Dataset, Reader, SVD  # Importing necessary modules from surprise library
from surprise.model_selection import train_test_split  # Importing train_test_split function

# Initializing a Reader object with the rating scale
reader = Reader(rating_scale=(1, 5))

# Retrieving unique values of the 'Review Rating' column from the DataFrame df and sorting them
unique_rating = sorted(df['Review Rating'].unique())


# Loading data from DataFrame into a Surprise Dataset object
surprise_data = Dataset.load_from_df(df[['Customer ID', 'Item Purchased', 'Review Rating']], reader)

# Splitting the dataset into training and testing sets
trainset, testset = train_test_split(surprise_data, test_size=0.2, random_state=1)

# Creating an instance of the SVD (Singular Value Decomposition) model
model = SVD()

# Training the model on the training set
model.fit(trainset)
# Infinite loop to repeatedly ask for customer identification code
while True:
    try:
        # Prompting the user to enter their identification code
        customer_identification_code = int(input('Enter your ID please: '))

        # Checking if the entered identification code is in the DataFrame's 'Customer ID' column
        if customer_identification_code in df['Customer ID'].unique():
            # Exiting the loop if the identification code is valid
            break
        else:
            # Printing a message indicating invalid ID if the identification code is not found in the DataFrame
            print(f"{Fore.YELLOW}INVALID ID{Style.RESET_ALL}")
    except ValueError:
        # Handling the ValueError exception if the input cannot be converted to an integer
        print(f"{Fore.RED}Invalid input. Please enter a valid integer.{Fore.RED}")
# Out:
# Enter your ID please: 3745

# %%
# Extracting the list of products purchased by a specific customer using their identification code
products_user_rated = df[df['Customer ID'] == customer_identification_code]['Item Purchased'].tolist()

# Obtaining the list of all unique products available
all_products = df['Item Purchased'].unique()

# Finding the products that the user has not rated yet
unrated_products = set(all_products) - set(products_user_rated)

# Generating predictions for the user's ratings for the unrated products using a model
user_predictions = [model.predict(customer_identification_code, product) for product in unrated_products]

# Prompting the user to input the number of product recommendations they desire
top_n = int(input('Enter how many product recommendations you want: '))

# Selecting the top n recommended products based on estimated ratings
recommended_products = sorted(user_predictions, key=lambda x: x.est, reverse=True)[:top_n]

# Extracting the IDs of the recommended products
recommended_product_ids = [product.iid for product in recommended_products]
# Printing the top recommended products for the customer with their identification code
print(f"\nTop{Fore.GREEN} {top_n} recommended products for Customer {customer_identification_code}: {recommended_product_ids}")
# Out:
# Enter how many product recommendations you want: 5
#
# Top 5 recommended products for Customer 3745: ['Sandals', 'Gloves', 'Boots', 'Sneakers', 'Skirt']
